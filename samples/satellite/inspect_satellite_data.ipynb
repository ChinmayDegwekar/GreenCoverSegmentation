# %%
# cd to the folder in drive where this file is present
# %cd drive/My\ Drive/MinorProject/Mask_RCNN/samples/satellite/
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/MinorProject/Mask_RCNN/samples/satellite/'
# /content

# %%
import os
import sys
import itertools
import math
import logging
import json
import re
import random
from collections import OrderedDict
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.lines as lines
from matplotlib.patches import Polygon

# %%
ROOT_DIR = os.getcwd()
print(ROOT_DIR)
if ROOT_DIR.endswith("samples/satellite"):
    # Go up two levels to the repo root
    ROOT_DIR = os.path.dirname(os.path.dirname(ROOT_DIR))

print(ROOT_DIR)
# Out:
# /content/drive/My Drive/MinorProject/Mask_RCNN/samples/satellite
# /content/drive/My Drive/MinorProject/Mask_RCNN

# %%
# Out:
# /content/drive/My Drive/MinorProject/Mask_RCNN/samples/satellite
# /content/drive/My Drive/MinorProject/Mask_RCNN
# /content/drive/My Drive/MinorProject/Mask_RCNN/mask_rcnn_coco.h5
# /content/drive/My Drive/MinorProject/Mask_RCNN/logs
# Using TensorFlow backend.

# %%
config = satellite.SatelliteConfig()
SATELLITE_DIR = os.path.join(ROOT_DIR, "datasets/")
print(SATELLITE_DIR)
print(config.NAME)
# Out:
# /content/drive/My Drive/MinorProject/Mask_RCNN/datasets/
# satellite

# %%
#DATASET LOADING


# Load dataset
# Get the dataset from the releases page
# https://github.com/matterport/Mask_RCNN/releases
dataset = satellite.SatelliteDataset()
dataset.load_satellite(SATELLITE_DIR, "train")

# Must call before using the dataset
dataset.prepare()

print("Image Count: {}".format(len(dataset.image_ids)))
print("Class Count: {}".format(dataset.num_classes))
for i, info in enumerate(dataset.class_info):
    print("{:3}. {:50}".format(i, info['name']))
# Out:
# img_3227.png :added
# img_3228.png :added
# img_3229.png :added
# img_3230.png :added
# img_3243.png :added
# img_3282.png :added
# img_3305.png :added
# img_3312.png :added
# img_3324.png :added
# img_3325.png :added
# img_3326.png :added
# img_3327.png :added
# img_3339.png :added
# img_3340.png :added
# img_3343.png :added
# img_3344.png :added
# img_6031.png :added
# img_6067.png :added
# img_6068.png :added
# img_6071.png :added
# img_6072.png :added
# img_6073.png :added
# img_6074.png :added
# img_6097.png :added
# img_6098.png :added
# img_6102.png :added
# img_6113.png :added
# img_6116.png :added
# img_6117.png :added
# img_6122.png :added
# img_6129.png :added
# img_6130.png :added
# img_6137.png :added
# img_6187.png :added
# img_6190.png :added
# img_6197.png :added
# img_6200.png :added
# img_6215.png :added
# img_6223.png :added
# img_6283.png :added
# img_6284.png :added
# img_6285.png :added
# img_6323.png :added
# img_6324.png :added
# img_6383.png :added
# img_6423.png :added
# img_6481.png :added
# img_6482.png :added
# img_6509.png :added
# img_6512.png :added
# Image Count: 50
# Class Count: 4
#   0. BG
#   1. water
#   2. built_up
#   3. green_cover

# %%
#DISPLAY SAMPLES

# Load and display random samples
image_ids = np.random.choice(dataset.image_ids, 4)
for image_id in image_ids:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset.class_names)
